# %% [markdown]
# # Моделювання багатошарових нейронних мереж прямого поширення (MLP — Multilayer Perceptron)

# %% [markdown]
# а) Створити двошарову нейронну мережу прямого поширення з сигмоїдальною активаційною функцією 'logsig' з двома входами. Навчити штучну нейронну мережу обчислювати значення функції на основі методу зворотного поширення помилки.

# %%
# Імпортуємо необхідні бібліотеки
import os
import tensorflow as tf
# Вимкнути використання GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import numpy as np

# %%
# Вхідні дані
X = np.array([[1, -2], 
              [1, -1], 
              [3, -2], 
              [3, -1]])  

# Вихідні дані
y = np.array([2, 1, 0, -3])

# %%
# Створення моделі
model = Sequential()

# Прихований шар: 5 нейронів, sigmoid, вхід з 2 ознак
model.add(Dense(5, input_dim=2, activation='sigmoid'))

# Вихідний шар: 1 нейрон з лінійною активацією
model.add(Dense(1, activation='linear'))

# Компіляція моделі для регресії
optimizer = Adam(learning_rate=0.3)
model.compile(optimizer=optimizer, 
              loss='mean_squared_error', 
              metrics=['mae'])

# %%
# Навчання моделі
model.fit(X, y, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 1/1 - 1s - 849ms/step - loss: 3.4457 - mae: 1.4610
# Epoch 2/100
# 1/1 - 0s - 54ms/step - loss: 3.6521 - mae: 1.8419
# Epoch 3/100
# 1/1 - 0s - 37ms/step - loss: 2.7261 - mae: 1.5224
# Epoch 4/100
# 1/1 - 0s - 29ms/step - loss: 2.5038 - mae: 1.2867
# Epoch 5/100
# 1/1 - 0s - 28ms/step - loss: 2.1824 - mae: 1.1917
# Epoch 6/100
# 1/1 - 0s - 27ms/step - loss: 1.4174 - mae: 0.9547
# Epoch 7/100
# 1/1 - 0s - 26ms/step - loss: 0.8569 - mae: 0.8971
# Epoch 8/100
# 1/1 - 0s - 30ms/step - loss: 0.7473 - mae: 0.8385
# Epoch 9/100
# 1/1 - 0s - 47ms/step - loss: 0.3491 - mae: 0.5141
# Epoch 10/100
# 1/1 - 0s - 50ms/step - loss: 0.1628 - mae: 0.3748
# Epoch 11/100
# 1/1 - 0s - 43ms/step - loss: 0.4783 - mae: 0.6566
# Epoch 12/100
# 1/1 - 0s - 32ms/step - loss: 0.3268 - mae: 0.4443
# Epoch 13/100
# 1/1 - 0s - 33ms/step - loss: 0.2668 - mae: 0.4902
# Epoch 14/100
# 1/1 - 0s - 31ms/step - loss: 0.3136 - mae: 0.4866
# Epoch 15/100
# 1/1 - 0s - 30ms/step - loss: 0.1402 - mae: 0.3112
# Epoch 16/100
# 1/1 - 0s - 28ms/step - loss: 0.0335 - mae: 0.1758
# Epoch 17/100
# 1/1 - 0s - 30ms/step - loss: 0.1020 - mae: 0.2800
# Epoch 18/100
# 1/1 - 0s - 28ms/step - loss: 0.1510 - mae: 0.2921
# Epoch 19/100
# 1/1 - 0s - 28ms/step - loss: 0.0938 - mae: 0.2763
# Epoch 20/100
# 1/1 - 0s - 26ms/step - loss: 0.0633 - mae: 0.2154
# Epoch 21/100
# 1/1 - 0s - 25ms/step - loss: 0.1254 - mae: 0.3236
# Epoch 22/100
# 1/1 - 0s - 25ms/step - loss: 0.1513 - mae: 0.3455
# Epoch 23/100
# 1/1 - 0s - 31ms/step - loss: 0.0844 - mae: 0.2782
# Epoch 24/100
# 1/1 - 0s - 26ms/step - loss: 0.0407 - mae: 0.1804
# Epoch 91/100
# 1/1 - 0s - 30ms/step - loss: 5.5524e-05 - mae: 0.0055
# Epoch 92/100
# 1/1 - 0s - 30ms/step - loss: 4.9223e-05 - mae: 0.0065
# Epoch 93/100
# 1/1 - 0s - 28ms/step - loss: 5.4629e-05 - mae: 0.0068
# Epoch 94/100
# 1/1 - 0s - 30ms/step - loss: 9.3220e-05 - mae: 0.0095
# Epoch 95/100
# 1/1 - 0s - 29ms/step - loss: 8.2313e-05 - mae: 0.0089
# Epoch 96/100
# 1/1 - 0s - 30ms/step - loss: 4.0560e-05 - mae: 0.0057
# Epoch 97/100
# 1/1 - 0s - 28ms/step - loss: 3.0055e-05 - mae: 0.0049
# Epoch 98/100
# 1/1 - 0s - 34ms/step - loss: 1.9359e-05 - mae: 0.0039
# Epoch 99/100
# 1/1 - 0s - 29ms/step - loss: 6.0348e-06 - mae: 0.0021
# Epoch 100/100
# 1/1 - 0s - 30ms/step - loss: 2.3900e-05 - mae: 0.0043

# %%
# Оцінка моделі
loss, mae = model.evaluate(X, y, verbose=0)
print(f'Втрати (MSE): {loss}, MAE: {mae}')

# Прогнозування
predictions = model.predict(X)

# Виведення навчальних значень та прогнозів
print(f"{'X1':>4} {'X2':>4} {'Actual':>10} {'Prediction':>10}")
print("-" * 34)
for x, actual, pred in zip(X, y, predictions):
    print(f"{x[0].item():>4} {x[1].item():>4} {actual:>10} {pred.item():>10.4f}")
# Out:
# Втрати (MSE): 3.703371112351306e-05, MAE: 0.005385100841522217
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#   X1   X2     Actual Prediction
# ----------------------------------
#    1   -2          2     1.9922
#    1   -1          1     0.9914
#    3   -2          0    -0.0023
#    3   -1         -3    -3.0028

# %% [markdown]
# б) Створити двошарову нейронну мережу прямого поширення з лінійною активаційною функцією 'purelin' з двома входами. Навчити штучну нейронну мережу обчислювати значення функції на основі методу зворотного поширення помилки.

# %%
# Створення моделі
model = Sequential()

# Прихований шар: 5 нейронів,  вхід з 2 ознак
model.add(Dense(5, input_dim=2, activation='linear'))

# Вихідний шар: 1 нейрон з лінійною активацією
model.add(Dense(1, activation='linear'))

# Компіляція моделі для регресії
optimizer = Adam(learning_rate=0.3)
model.compile(optimizer=optimizer, 
              loss='mean_squared_error', 
              metrics=['mae'])

# %%
# Навчання моделі
model.fit(X, y, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 1/1 - 1s - 823ms/step - loss: 14.3538 - mae: 3.2282
# Epoch 2/100
# 1/1 - 0s - 25ms/step - loss: 12.1547 - mae: 3.2047
# Epoch 3/100
# 1/1 - 0s - 29ms/step - loss: 10.9433 - mae: 2.9648
# Epoch 4/100
# 1/1 - 0s - 26ms/step - loss: 4.5123 - mae: 2.0318
# Epoch 5/100
# 1/1 - 0s - 28ms/step - loss: 3.9799 - mae: 1.5834
# Epoch 6/100
# 1/1 - 0s - 27ms/step - loss: 6.8475 - mae: 1.9006
# Epoch 7/100
# 1/1 - 0s - 28ms/step - loss: 6.7303 - mae: 1.8792
# Epoch 8/100
# 1/1 - 0s - 31ms/step - loss: 4.7307 - mae: 1.5764
# Epoch 9/100
# 1/1 - 0s - 27ms/step - loss: 3.2334 - mae: 1.3840
# Epoch 10/100
# 1/1 - 0s - 28ms/step - loss: 2.5710 - mae: 1.2993
# Epoch 11/100
# 1/1 - 0s - 29ms/step - loss: 2.2776 - mae: 1.3512
# Epoch 12/100
# 1/1 - 0s - 30ms/step - loss: 2.0313 - mae: 1.3233
# Epoch 13/100
# 1/1 - 0s - 31ms/step - loss: 1.7312 - mae: 1.2286
# Epoch 14/100
# 1/1 - 0s - 32ms/step - loss: 1.3947 - mae: 1.0771
# Epoch 15/100
# 1/1 - 0s - 30ms/step - loss: 1.0861 - mae: 0.8811
# Epoch 16/100
# 1/1 - 0s - 31ms/step - loss: 0.8471 - mae: 0.6641
# Epoch 17/100
# 1/1 - 0s - 27ms/step - loss: 0.6332 - mae: 0.5136
# Epoch 18/100
# 1/1 - 0s - 34ms/step - loss: 0.3891 - mae: 0.5000
# Epoch 19/100
# 1/1 - 0s - 26ms/step - loss: 0.2507 - mae: 0.5000
# Epoch 20/100
# 1/1 - 0s - 27ms/step - loss: 0.4016 - mae: 0.5661
# Epoch 21/100
# 1/1 - 0s - 30ms/step - loss: 0.6065 - mae: 0.7392
# Epoch 22/100
# 1/1 - 0s - 30ms/step - loss: 0.6347 - mae: 0.6895
# Epoch 23/100
# 1/1 - 0s - 29ms/step - loss: 0.7681 - mae: 0.5238
# Epoch 24/100
# 1/1 - 0s - 30ms/step - loss: 0.8485 - mae: 0.5074
# Epoch 25/100
# 1/1 - 0s - 30ms/step - loss: 0.6424 - mae: 0.5500
# Epoch 26/100
# 1/1 - 0s - 32ms/step - loss: 0.5369 - mae: 0.6717
# Epoch 27/100
# 1/1 - 0s - 42ms/step - loss: 0.4320 - mae: 0.6101
# Epoch 28/100
# 1/1 - 0s - 58ms/step - loss: 0.2715 - mae: 0.5000
# Epoch 29/100
# 1/1 - 0s - 57ms/step - loss: 0.3200 - mae: 0.5000
# Epoch 30/100
# 1/1 - 0s - 32ms/step - loss: 0.3435 - mae: 0.5000
# Epoch 31/100
# 1/1 - 0s - 28ms/step - loss: 0.3518 - mae: 0.5024
# Epoch 32/100
# 1/1 - 0s - 29ms/step - loss: 0.4649 - mae: 0.6382
# Epoch 33/100
# 1/1 - 0s - 29ms/step - loss: 0.4629 - mae: 0.6370
# Epoch 34/100
# 1/1 - 0s - 31ms/step - loss: 0.4537 - mae: 0.5462
# Epoch 35/100
# 1/1 - 0s - 29ms/step - loss: 0.4537 - mae: 0.5000
# Epoch 36/100
# 1/1 - 0s - 31ms/step - loss: 0.3586 - mae: 0.5000
# Epoch 37/100
# 1/1 - 0s - 28ms/step - loss: 0.3319 - mae: 0.5000
# Epoch 38/100
# 1/1 - 0s - 28ms/step - loss: 0.2854 - mae: 0.5000
# Epoch 39/100
# 1/1 - 0s - 29ms/step - loss: 0.2577 - mae: 0.5000
# Epoch 40/100
# 1/1 - 0s - 27ms/step - loss: 0.2928 - mae: 0.5000
# Epoch 41/100
# 1/1 - 0s - 27ms/step - loss: 0.2876 - mae: 0.5000
# Epoch 42/100
# 1/1 - 0s - 38ms/step - loss: 0.3361 - mae: 0.5000
# Epoch 43/100
# 1/1 - 0s - 37ms/step - loss: 0.3289 - mae: 0.5000
# Epoch 44/100
# 1/1 - 0s - 36ms/step - loss: 0.3301 - mae: 0.5000
# Epoch 45/100
# 1/1 - 0s - 32ms/step - loss: 0.3094 - mae: 0.5000
# Epoch 46/100
# 1/1 - 0s - 30ms/step - loss: 0.2781 - mae: 0.5000
# Epoch 47/100
# 1/1 - 0s - 28ms/step - loss: 0.2704 - mae: 0.5000
# Epoch 48/100
# 1/1 - 0s - 30ms/step - loss: 0.2504 - mae: 0.5000
# Epoch 49/100
# 1/1 - 0s - 31ms/step - loss: 0.2675 - mae: 0.5000
# Epoch 50/100
# 1/1 - 0s - 31ms/step - loss: 0.2651 - mae: 0.5000
# Epoch 51/100
# 1/1 - 0s - 30ms/step - loss: 0.2834 - mae: 0.5000
# Epoch 52/100
# 1/1 - 0s - 28ms/step - loss: 0.2820 - mae: 0.5000
# Epoch 53/100
# 1/1 - 0s - 28ms/step - loss: 0.2822 - mae: 0.5000
# Epoch 54/100
# 1/1 - 0s - 29ms/step - loss: 0.2747 - mae: 0.5000
# Epoch 55/100
# 1/1 - 0s - 35ms/step - loss: 0.2627 - mae: 0.5000
# Epoch 56/100
# 1/1 - 0s - 28ms/step - loss: 0.2587 - mae: 0.5000
# Epoch 57/100
# 1/1 - 0s - 27ms/step - loss: 0.2508 - mae: 0.5000
# Epoch 58/100
# 1/1 - 0s - 31ms/step - loss: 0.2570 - mae: 0.5000
# Epoch 59/100
# 1/1 - 0s - 27ms/step - loss: 0.2561 - mae: 0.5000
# Epoch 60/100
# 1/1 - 0s - 29ms/step - loss: 0.2649 - mae: 0.5000
# Epoch 61/100
# 1/1 - 0s - 32ms/step - loss: 0.2622 - mae: 0.5000
# Epoch 62/100
# 1/1 - 0s - 29ms/step - loss: 0.2645 - mae: 0.5000
# Epoch 63/100
# 1/1 - 0s - 36ms/step - loss: 0.2572 - mae: 0.5000
# Epoch 64/100
# 1/1 - 0s - 36ms/step - loss: 0.2561 - mae: 0.5000
# Epoch 65/100
# 1/1 - 0s - 36ms/step - loss: 0.2508 - mae: 0.5000
# Epoch 66/100
# 1/1 - 0s - 32ms/step - loss: 0.2526 - mae: 0.5000
# Epoch 67/100
# 1/1 - 0s - 33ms/step - loss: 0.2518 - mae: 0.5000
# Epoch 68/100
# 1/1 - 0s - 35ms/step - loss: 0.2554 - mae: 0.5000
# Epoch 69/100
# 1/1 - 0s - 31ms/step - loss: 0.2552 - mae: 0.5000
# Epoch 70/100
# 1/1 - 0s - 30ms/step - loss: 0.2564 - mae: 0.5000
# Epoch 71/100
# 1/1 - 0s - 31ms/step - loss: 0.2541 - mae: 0.5000
# Epoch 72/100
# 1/1 - 0s - 33ms/step - loss: 0.2532 - mae: 0.5000
# Epoch 73/100
# 1/1 - 0s - 58ms/step - loss: 0.2508 - mae: 0.5000
# Epoch 74/100
# 1/1 - 0s - 27ms/step - loss: 0.2510 - mae: 0.5000
# Epoch 75/100
# 1/1 - 0s - 26ms/step - loss: 0.2505 - mae: 0.5000
# Epoch 76/100
# 1/1 - 0s - 27ms/step - loss: 0.2520 - mae: 0.5000
# Epoch 77/100
# 1/1 - 0s - 34ms/step - loss: 0.2520 - mae: 0.5000
# Epoch 78/100
# 1/1 - 0s - 27ms/step - loss: 0.2529 - mae: 0.5000
# Epoch 79/100
# 1/1 - 0s - 29ms/step - loss: 0.2518 - mae: 0.5000
# Epoch 80/100
# 1/1 - 0s - 29ms/step - loss: 0.2516 - mae: 0.5000
# Epoch 81/100
# 1/1 - 0s - 31ms/step - loss: 0.2503 - mae: 0.5000
# Epoch 82/100
# 1/1 - 0s - 31ms/step - loss: 0.2505 - mae: 0.5000
# Epoch 83/100
# 1/1 - 0s - 30ms/step - loss: 0.2501 - mae: 0.5000
# Epoch 84/100
# 1/1 - 0s - 33ms/step - loss: 0.2509 - mae: 0.5000
# Epoch 85/100
# 1/1 - 0s - 38ms/step - loss: 0.2509 - mae: 0.5000
# Epoch 86/100
# 1/1 - 0s - 28ms/step - loss: 0.2513 - mae: 0.5000
# Epoch 87/100
# 1/1 - 0s - 29ms/step - loss: 0.2509 - mae: 0.5000
# Epoch 88/100
# 1/1 - 0s - 29ms/step - loss: 0.2507 - mae: 0.5000
# Epoch 89/100
# 1/1 - 0s - 27ms/step - loss: 0.2502 - mae: 0.5000
# Epoch 90/100
# 1/1 - 0s - 28ms/step - loss: 0.2501 - mae: 0.5000
# Epoch 91/100
# 1/1 - 0s - 31ms/step - loss: 0.2502 - mae: 0.5000
# Epoch 92/100
# 1/1 - 0s - 29ms/step - loss: 0.2503 - mae: 0.5000
# Epoch 93/100
# 1/1 - 0s - 30ms/step - loss: 0.2506 - mae: 0.5000
# Epoch 94/100
# 1/1 - 0s - 31ms/step - loss: 0.2504 - mae: 0.5000
# Epoch 95/100
# 1/1 - 0s - 30ms/step - loss: 0.2505 - mae: 0.5000
# Epoch 96/100
# 1/1 - 0s - 32ms/step - loss: 0.2502 - mae: 0.5000
# Epoch 97/100
# 1/1 - 0s - 30ms/step - loss: 0.2502 - mae: 0.5000
# Epoch 98/100
# 1/1 - 0s - 28ms/step - loss: 0.2500 - mae: 0.5000
# Epoch 99/100
# 1/1 - 0s - 30ms/step - loss: 0.2501 - mae: 0.5000
# Epoch 100/100
# 1/1 - 0s - 29ms/step - loss: 0.2502 - mae: 0.5000

# %%
# Оцінка моделі
loss, mae = model.evaluate(X, y, verbose=0)
print(f'Втрати (MSE): {loss}, MAE: {mae}')

# Прогнозування
predictions = model.predict(X)

# Виведення навчальних значень та прогнозів
print(f"{'X1':>4} {'X2':>4} {'Actual':>10} {'Prediction':>10}")
print("-" * 34)
for x, actual, pred in zip(X, y, predictions):
    print(f"{x[0].item():>4} {x[1].item():>4} {actual:>10} {pred.item():>10.4f}")
# Out:
# Втрати (MSE): 0.2502131462097168, MAE: 0.4999999701976776
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   X1   X2     Actual Prediction
# ----------------------------------
#    1   -2          2     2.4818
#    1   -1          1     0.4935
#    3   -2          0    -0.4915
#    3   -1         -3    -2.4798

# %% [markdown]
# Якщо всі шари у  нейронній мережі використовують лінійні активаційні функції,
# то вся модель стає еквівалентною звичайному лінійному виразу, незалежно від кількості шарів.
# Це означає, що така мережа не зможе моделювати нелінійні залежності між вхідними та вихідними даними.
# Вся багатошарова мережа еквівалентна одному лінійному нейрону (тобто лінійній регресії).
# Тому додавання додаткових лінійних шарів у такій конфігурації не приносить жодної нової користі
# — всю роботу можна виконати одним лінійним нейроном.

# %% [markdown]
# # Обчислити 10 значень функції sin(x1) + cos(x2) - cos(x3) по заданих значення аргументів x1=1/2, x2=1/5, x3=1/4 та їх варіаціях з кроком ±1.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import Callback
from tabulate import tabulate  

class CustomEarlyStopping(Callback):
    """Кастомний колбек для зупинки, коли MSE < 1e-5."""
    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get("loss")
        if current_loss is not None and current_loss < 1e-5:
            print(f"\nЗупинка на {epoch+1}-й епосі: MSE < 1e-5")
            self.model.stop_training = True


# Функція для обчислення цільових значень
def target_function(x1, x2, x3):
    return np.sin(x1) + np.cos(x2) - np.cos(x3)

# Генеруємо дані
x1_values = np.linspace(0.5 - 5, 0.5 + 4, 10)
x2_values = np.linspace(0.2 - 5, 0.2 + 4, 10)
x3_values = np.linspace(0.25 - 5, 0.25 + 4, 10)
X = np.column_stack((x1_values, x2_values, x3_values))
Y = np.array([target_function(x1, x2, x3) for x1, x2, x3 in X])

# Функція для створення та навчання моделі
def build_and_train_model(activation, optimizer_class, lr=0.03):
    optimizer = optimizer_class(learning_rate=lr)

    # Створення моделі
    model = Sequential()
    model.add(Dense(5, input_dim=3, activation=activation))  # Прихований шар
    model.add(Dense(1, activation='linear'))  # Вихідний шар

    early_stopping = CustomEarlyStopping()
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    history = model.fit(X, Y, epochs=2000, verbose=0, callbacks=[early_stopping])

    # Отримання втрати та кількості епох
    loss = history.history['loss'][-1]
    epochs = len(history.history['loss'])
    predictions = model.predict(X)

    return loss, epochs, predictions

# Списки активаційних функцій та оптимізаторів
activations = ['tanh', 'relu', 'sigmoid']
optimizer_classes = [Adam, SGD, RMSprop]

# Збереження результатів
results = []

# Збір даних у циклі
for activation in activations:
    for optimizer_class in optimizer_classes:
        loss, epochs, _ = build_and_train_model(activation, optimizer_class)
        optimizer_name = optimizer_class.__name__
        results.append((activation, optimizer_name, f"{loss:.6f}", epochs))

# Вивід таблиці
headers = ["Activation", "Optimizer", "Loss", "Epochs"]
print(tabulate(results, headers=headers, tablefmt="pretty"))

# Пошук найкращої комбінації
best_result = min(results, key=lambda x: float(x[2]))
print("\nНайкраща комбінація за похибкою:")
print(f"Активація: {best_result[0]}, Оптимізатор: {best_result[1]}, "
      f"Втрата: {best_result[2]}, Епохи: {best_result[3]}")
# Out:
# Зупинка на 363-й епосі: MSE < 1e-5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Зупинка на 744-й епосі: MSE < 1e-5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# +------------+-----------+----------+--------+
# | Activation | Optimizer |   Loss   | Epochs |
# +------------+-----------+----------+--------+
# |    tanh    |   Adam    | 0.000010 |  363   |
# |    tanh    |    SGD    | 0.156832 |  2000  |
# |    tanh    |  RMSprop  | 0.005312 |  2000  |
# |    relu    |   Adam    | 0.007204 |  2000  |
# |    relu    |    SGD    | 0.431553 |  2000  |
# |    relu    |  RMSprop  | 0.070482 |  2000  |
# |  sigmoid   |   Adam    | 0.000010 |  744   |
# |  sigmoid   |    SGD    | 0.091660 |  2000  |
# |  sigmoid   |  RMSprop  | 0.011379 |  2000  |
# +------------+-----------+----------+--------+
#
# Найкраща комбінація за похибкою:
# Активація: tanh, Оптимізатор: Adam, Втрата: 0.000010, Епохи: 363
